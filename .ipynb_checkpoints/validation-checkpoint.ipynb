# %%
import pandas as pd

# %%
plants_all = pd.read_csv("plant_list.csv", sep=";").fillna("")

# %%
len(plants_all)
# Out:
# 67

# %%
for i in range(0,7):
    print(sum(plants_all["Profficiency"]==i))
# Out:
# 7
# 0
# 16
# 20
# 14
# 9
# 1

# %%
plants_all.dtypes
# Out:
# Name            object
# Profficiency     int64
# Forest            bool
# Plains            bool
# Mountain          bool
# Cave              bool
# Coast             bool
# t1a             object
# t1b             object
# t2a             object
# t2b             object
# Image           object
# Flavour         object
# Event           object
# dtype: object

# %%
def format_text(cond):
    cond = cond.strip()
    if len(cond)==0:
        return cond
    cond = list(cond)
    if cond[-1]==".":
        cond[-1]=":"
    else:
        cond +=[":"]
    cond = "".join(cond)
    cond =cond.replace(".",",")
    return cond

# %%
plants_all["t2a"] = plants_all["t2a"].apply(format_text)
plants_all["t1a"] = plants_all["t1a"].apply(format_text)

# %%
plants_all.to_csv("plant_list_mod.csv", sep=";")

# %%
plants_all.iloc[60:]
# Out:
#                Name  Profficiency  Forest  Plains  Mountain   Cave  Coast  \
# 60     Neck Breaker             4   False   False      True  False  False
# 61    Immortal Lily             6    True    True      True   True   True
# 62     Bond Breaker             5   False   False      True  False  False
# 63  Symbiotic Death             5    True   False     False  False  False
# 64     Ocean's Test             5   False   False     False  False   True
# 65    Thief's dream             5   False   False     False   True  False
# 66     Giant Scales             5   False    True     False  False  False
#
#                                   t1a  \
# 60                            Planted
# 61  Consumed (does not end when used)
# 62                          Permanent
# 63                          Permanent
# 64                          Permanent
# 65                          Permanent
# 66                Permanent (Giant A)
#
#                                                   t1b  \
# 60  Wherever the plant is currently planted it emi...
# 61  If unconscious on your turn, instead of death-...
# 62  You are spiritually free of earthly bonds. You...
# 63  Your skin gets a slightly greenish hue. Once p...
# 64  The sea considers you worthy. You gain swimmin...
# 65  Wood and stone obstacles that are up to 10 ft....
# 66   You gain +2 to Strength, +2 to Constitution a...
#
#                                        t2a  \
# 60
# 61  Laboratory. 10000g materials. Consumed
# 62
# 63
# 64
# 65
# 66                     Permanent (Giant B)
#
#                                                   t2b                 Image  \
# 60                                                     temp_neckbreaker.jpg
# 61              You do not age for the next 25 years.            dragon.jpg
# 62                                                             meditate.jpg
# 63                                                          poisonplant.jpg
# 64                                                               trench.jpg
# 65                                                              fossile.jpg
# 66  You gain +10 to movement speed, cannot be para...             giant.jpg
#
#                                    Flavour  \
# 60
# 61  Forever unchanging. Forever beautiful.
# 62
# 63
# 64
# 65
# 66
#
#                                                 Event
# 60  The Neck Breaker Plant grows out of a thin pea...
# 61   You encounter a CR 17+ dragon (at DM discreti...
# 62  To get the effect you must meditate under the ...
# 63  An old inscription dares you to eat as many le...
# 64  The plant grows at the bottom of a 3000ft deep...
# 65  You have tracked the general location of this ...
# 66  A pair of Storm Giants roam the area. On their...

# %%
plants_all["Forest"].apply(lambda x: x+" "+str(len(x)))
# Out:
# 0      False 5
# 1       True 4
# 2       True 4
# 3       True 4
# 4       True 4
# 5      False 5
# 6       True 4
# 7      False 5
# 8      False 5
# 9      False 5
# 10      True 4
# 11     False 5
# 12     False 5
# 13      True 4
# 14      True 4
# 15     False 5
# 16      True 4
# 17      True 4
# 18     False 5
# 19     False 6
# 20     False 5
# 21      True 4
# 22      True 4
# Name: Forest, dtype: object

# %%
proff = 0
terrain = "Plains"
plants_relevant = plants_all[(plants_all[terrain]) & (plants_all["Profficiency"]<=int(proff))]
plants_relevant
# Out:
#            Name  Profficiency  Forest  Plains  Mountain   Cave  Coast  \
# 0  Black Chilli             0   False    True     False  False  False
# 1     Wild Rose             0    True    True      True   True   True
# 3         Berry             0    True    True      True  False   True
# 5        Carrot             0   False    True     False  False  False
#
#         t1a                            t1b                          t2a  \
# 0  Consumed        Has a very spicy taste.  Combines with Corpse flower
# 1                 Intrinsically beautiful.
# 3  Consumed                   Regain 1 hp.
# 5  Consumed  Acts as daily ration of food.                       Carved
#
#                                          t2b            Image  \
# 0  Creates a rare spice, that sells for 50g.  black_chili.jpg
# 1                                               wild_rose.jpg
# 3                                                   berry.jpg
# 5                       A makeshift whistle.       carrot.jpg
#
#                                 Flavour Event
# 0
# 1  Sometimes a flower is just a flower.
# 3
# 5

# %%
plants_relevant
# Out:
#         Name  Profficiency  Forest  Plains  Mountain  Cave  Coast t1a  \
# 1  Wild Rose             0    True    True      True  True   True
#
#                         t1b t2a t2b          Image  \
# 1  Intrinsically beautiful.          wild_rose.jpg
#
#                                 Flavour Event
# 1  Sometimes a flower is just a flower.

# %%
plants_relevant.sample()["Name"].iloc[0]
# Out:
# 'Carrot'
