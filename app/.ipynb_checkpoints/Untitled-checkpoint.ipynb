# %%
import pandas as pd

# %%
plants_all = pd.read_csv("plant_list.csv", sep=";").fillna("")

# %%
plants_all
# Out:
#                Name  Profficiency  Forest  Plains  Mountain   Cave  Coast  \
# 0      Black Chilli             0   False    True     False  False  False
# 1         Wild Rose             0    True    True      True   True   True
# 2    Medical Leaves             2    True   False     False   True  False
# 3             Berry             0    True    True      True  False   True
# 4  Fast-growing Ivy             0    True   False     False  False  False
# 5            Carrot             0   False    True     False  False  False
# 6       Sturdy Vine             0    True   False      True  False  False
#
#             t1a                                  t1b  \
# 0      Consumed              Has a very spicy taste.
# 1                           Intrinsically beautiful.
# 2  Bonus action  Stabilizes an unconscious creature.
# 3      Consumed                         Regain 1 hp.
# 4       Trimmed            Can be shaped into a hat.
# 5      Consumed        Acts as daily ration of food.
# 6       Carried               Acts as 10 ft of rope.
#
#                            t2a                                        t2b  \
# 0  Combines with Corpse flower  Creates a rare spice, that sells for 50g.
# 1
# 2     Alchemy kit. 1g material                  Creates a healing potion.
# 3
# 4             Trimmed (3 days)         Can be shaped into basic clothing.
# 5                       Carved                       A makeshift whistle.
# 6
#
#              Image                               Flavour Event
# 0  black_chili.jpg
# 1    wild_rose.jpg  Sometimes a flower is just a flower.
# 2      athelas.jpg
# 3        berry.jpg
# 4          ivy.jpg
# 5       carrot.jpg
# 6        vines.jpg

# %%
proff = 0
terrain = "Plains"
plants_relevant = plants_all[(plants_all[terrain]) & (plants_all["Profficiency"]<=int(proff))]
plants_relevant
# Out:
#            Name  Profficiency  Forest  Plains  Mountain   Cave  Coast  \
# 0  Black Chilli             0   False    True     False  False  False
# 1     Wild Rose             0    True    True      True   True   True
# 3         Berry             0    True    True      True  False   True
# 5        Carrot             0   False    True     False  False  False
#
#         t1a                            t1b                          t2a  \
# 0  Consumed        Has a very spicy taste.  Combines with Corpse flower
# 1                 Intrinsically beautiful.
# 3  Consumed                   Regain 1 hp.
# 5  Consumed  Acts as daily ration of food.                       Carved
#
#                                          t2b            Image  \
# 0  Creates a rare spice, that sells for 50g.  black_chili.jpg
# 1                                               wild_rose.jpg
# 3                                                   berry.jpg
# 5                       A makeshift whistle.       carrot.jpg
#
#                                 Flavour Event
# 0
# 1  Sometimes a flower is just a flower.
# 3
# 5

# %%
plants_relevant
# Out:
#         Name  Profficiency  Forest  Plains  Mountain  Cave  Coast t1a  \
# 1  Wild Rose             0    True    True      True  True   True
#
#                         t1b t2a t2b          Image  \
# 1  Intrinsically beautiful.          wild_rose.jpg
#
#                                 Flavour Event
# 1  Sometimes a flower is just a flower.

# %%
plants_relevant.sample()["Name"].iloc[0]
# Out:
# 'Carrot'
