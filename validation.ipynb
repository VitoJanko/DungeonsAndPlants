# %%
import pandas as pd

# %%
plants_all = pd.read_csv("plant_list.csv", sep=";").fillna("")

# %%
len(plants_all)
# Out:
# 82

# %%
for habitat in ["Arctic", "Forest", "Coast", "Mountain", "Cave", "Plains"]:
    suma = sum(plants_all[habitat])
    print(f"{habitat} ({suma})")
    
    for i in range(0,7):
        if i!=1:
            possible = sum((plants_all["Profficiency"]<=i) & (plants_all[habitat]))
            count = sum((plants_all["Profficiency"]==i) & (plants_all[habitat]))

            ratio = int((count/possible)*100)
            print(f"Profficiency {i}: {count} ({ratio}%)")
    print("--")
# Out:
# Arctic (29)
# Profficiency 0: 4 (100%)
# Profficiency 2: 6 (60%)
# Profficiency 3: 9 (47%)
# Profficiency 4: 6 (24%)
# Profficiency 5: 3 (10%)
# Profficiency 6: 1 (3%)
# --
# Forest (36)
# Profficiency 0: 5 (100%)
# Profficiency 2: 9 (64%)
# Profficiency 3: 9 (39%)
# Profficiency 4: 9 (28%)
# Profficiency 5: 3 (8%)
# Profficiency 6: 1 (2%)
# --
# Coast (30)
# Profficiency 0: 3 (100%)
# Profficiency 2: 8 (72%)
# Profficiency 3: 8 (42%)
# Profficiency 4: 7 (26%)
# Profficiency 5: 3 (10%)
# Profficiency 6: 1 (3%)
# --
# Mountain (29)
# Profficiency 0: 4 (100%)
# Profficiency 2: 8 (66%)
# Profficiency 3: 8 (40%)
# Profficiency 4: 5 (20%)
# Profficiency 5: 3 (10%)
# Profficiency 6: 1 (3%)
# --
# Cave (21)
# Profficiency 0: 2 (100%)
# Profficiency 2: 4 (66%)
# Profficiency 3: 7 (53%)
# Profficiency 4: 5 (27%)
# Profficiency 5: 2 (10%)
# Profficiency 6: 1 (4%)
# --
# Plains (35)
# Profficiency 0: 4 (100%)
# Profficiency 2: 10 (71%)
# Profficiency 3: 11 (44%)
# Profficiency 4: 6 (19%)
# Profficiency 5: 3 (8%)
# Profficiency 6: 1 (2%)
# --

# %%
plants_all.dtypes
# Out:
# Name            object
# Profficiency     int64
# Arctic            bool
# Forest            bool
# Plains            bool
# Mountain          bool
# Cave              bool
# Coast             bool
# t1a             object
# t1b             object
# t2a             object
# t2b             object
# Image           object
# Flavour         object
# Event           object
# dtype: object

# %%
def format_text(cond):
    cond = cond.strip()
    if len(cond)==0:
        return cond
    cond = list(cond)
    if cond[-1]==".":
        cond[-1]=":"
    else:
        cond +=[":"]
    cond = "".join(cond)
    cond =cond.replace(".",",")
    return cond

# %%
plants_all["t2a"] = plants_all["t2a"].apply(format_text)
plants_all["t1a"] = plants_all["t1a"].apply(format_text)

# %%
plants_all.to_csv("plant_list_mod.csv", sep=";")

# %%
plants_all.iloc[60:]
# Out:
#                Name  Profficiency  Arctic  Forest  Plains  Mountain   Cave  \
# 60     Neck Breaker             4   False   False   False      True  False
# 61    Immortal Lily             6   False    True    True      True   True
# 62     Bond Breaker             5   False   False   False      True  False
# 63  Symbiotic Death             5   False    True   False     False  False
# 64      Oceans Test             5   False   False   False     False  False
# 65     Thiefs Dream             5   False   False   False     False   True
# 66     Giant Scales             5   False   False    True     False  False
#
#     Coast                                t1a  \
# 60  False                            Planted
# 61   True  Consumed (does not end when used)
# 62  False                          Permanent
# 63  False                          Permanent
# 64   True                          Permanent
# 65  False                          Permanent
# 66  False                Permanent (Giant A)
#
#                                                   t1b  \
# 60  Wherever the plant is currently planted it emi...
# 61  If unconscious on your turn, instead of death-...
# 62  You are spiritually free of earthly bonds. You...
# 63  Your skin gets a slightly greenish hue. Once p...
# 64  The sea considers you worthy. You gain swimmin...
# 65  Wood and stone obstacles that are up to 10 ft....
# 66   You gain +2 to Strength, +2 to Constitution a...
#
#                                        t2a  \
# 60
# 61  Laboratory. 10000g materials. Consumed
# 62
# 63
# 64
# 65
# 66                     Permanent (Giant B)
#
#                                                   t2b                 Image  \
# 60                                                     temp_neckbreaker.jpg
# 61              You do not age for the next 25 years.            dragon.jpg
# 62                                                             meditate.jpg
# 63                                                         poisonplants.jpg
# 64                                                               trench.jpg
# 65                                                              fossile.jpg
# 66  You gain +10 to movement speed, cannot be para...             giant.jpg
#
#                                    Flavour  \
# 60
# 61  Forever unchanging. Forever beautiful.
# 62
# 63
# 64
# 65
# 66
#
#                                                 Event
# 60  The Neck Breaker Plant grows out of a thin pea...
# 61   You encounter a CR 17+ dragon (at DM discreti...
# 62  To get the effect you must meditate under the ...
# 63  An old inscription dares you to eat as many pe...
# 64  A plant grows at the bottom of a 3000 ft. deep...
# 65  You have tracked the general location of this ...
# 66  A pair of Storm Giants roam the area. On their...

# %%
plants_all["Forest"].apply(lambda x: x+" "+str(len(x)))
# Out:
# 0      False 5
# 1       True 4
# 2       True 4
# 3       True 4
# 4       True 4
# 5      False 5
# 6       True 4
# 7      False 5
# 8      False 5
# 9      False 5
# 10      True 4
# 11     False 5
# 12     False 5
# 13      True 4
# 14      True 4
# 15     False 5
# 16      True 4
# 17      True 4
# 18     False 5
# 19     False 6
# 20     False 5
# 21      True 4
# 22      True 4
# Name: Forest, dtype: object

# %%
proff = 0
terrain = "Plains"
plants_relevant = plants_all[(plants_all[terrain]) & (plants_all["Profficiency"]<=int(proff))]
plants_relevant
# Out:
#            Name  Profficiency  Forest  Plains  Mountain   Cave  Coast  \
# 0  Black Chilli             0   False    True     False  False  False
# 1     Wild Rose             0    True    True      True   True   True
# 3         Berry             0    True    True      True  False   True
# 5        Carrot             0   False    True     False  False  False
#
#         t1a                            t1b                          t2a  \
# 0  Consumed        Has a very spicy taste.  Combines with Corpse flower
# 1                 Intrinsically beautiful.
# 3  Consumed                   Regain 1 hp.
# 5  Consumed  Acts as daily ration of food.                       Carved
#
#                                          t2b            Image  \
# 0  Creates a rare spice, that sells for 50g.  black_chili.jpg
# 1                                               wild_rose.jpg
# 3                                                   berry.jpg
# 5                       A makeshift whistle.       carrot.jpg
#
#                                 Flavour Event
# 0
# 1  Sometimes a flower is just a flower.
# 3
# 5

# %%
plants_relevant
# Out:
#         Name  Profficiency  Forest  Plains  Mountain  Cave  Coast t1a  \
# 1  Wild Rose             0    True    True      True  True   True
#
#                         t1b t2a t2b          Image  \
# 1  Intrinsically beautiful.          wild_rose.jpg
#
#                                 Flavour Event
# 1  Sometimes a flower is just a flower.

# %%
plants_relevant.sample()["Name"].iloc[0]
# Out:
# 'Carrot'

# %%
names = plants_all["Source"].apply(lambda x: x.split(",")[0])
sites = plants_all["Source"].apply(lambda x: x.split(",")[1] if len(x.split(","))>=2 else "")

# %%
for name, author, site in zip(plants_all.Name, names, sites):
    if len(site) > 0: 
        print(f"<b>{name}</b> by {author} ({site.strip()})")
# Out:
# <b>Black Chilli</b> by “The Chilly Factory” (https://thechillifactory.com/chilli-chili-chile-product-Hungarian%20Black)
# <b>Wild Rose</b> by LightField Studios (https://www.shutterstock.com/image-photo/close-view-beautiful-white-rose-flower-1101242228)
